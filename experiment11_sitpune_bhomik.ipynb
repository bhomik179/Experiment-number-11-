# %% [markdown]
# <a href="https://colab.research.google.com/github/bhomik179/Experiment-number-11-/blob/main/experiment11_sitpune_bhomik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 25070123172
#
# # Bhomik Keshi
#
# # Experiment 11:- To create data set and load data set in panda library

# %%
# This code is for the dataset creation



import pandas as pd

data = {
    "Roll No": [101, 102, 103, 104,105],
    "Gender": ["Female", "Male", "Female", "Male","Female"],
    "Department": ["Computer Science", "Mechanical", "Electronics", "Mechanical","Civil"],
    "CGPA": [8.7, 7.9, 9.1, 8.3,8.3]
}

df = pd.DataFrame(data)

df.to_csv("student_data.csv", index=False)

display(df)
print()
print()


df.shape
print("The number of rows and column\n",df.shape)
print()
print()


df.size
print("The size of the table is \n",df.size)
print()
print()




# This code is for all the necessary information in the code
df.info()
print()
print()

# To find the statisticals value in the table
# in this the 25,50,75 is known as quartile
df.describe()
print()
print()
# Out:
#    Roll No  Gender        Department  CGPA
# 0      101  Female  Computer Science   8.7
# 1      102    Male        Mechanical   7.9
# 2      103  Female       Electronics   9.1
# 3      104    Male        Mechanical   8.3
# 4      105  Female             Civil   8.3
# The number of rows and column
#  (5, 4)
#
#
# The size of the table is
#  20
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     5 non-null      int64
#  1   Gender      5 non-null      object
#  2   Department  5 non-null      object
#  3   CGPA        5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # **Below this code the datasheet from cars 93 have been used here**

# %%
# Upload the Dataset
import pandas as pd
import numpy as np

# Load the dataset
# Note: Ensure 'Cars93.csv' is in your current directory or Google Colab 'Files'
df1 = pd.read_csv('/content/Cars93.csv')

# Display the dataframe
display(df1)

# Check the number of rows and columns
print("The number of rows and columns:\n", df1.shape)
print()

# Check the total size (rows * columns)
print("The size of the table is:\n", df1.size)
print()

# Get necessary information about the dataframe (data types, null values)
df1.info()
print()

# To find the statistical values (includes quartiles 25%, 50%, 75%)
print("Statistical Summary (Quartiles included):\n")
print(df1.describe())
print()

# To display the first 5 rows
print("To display the first 5 rows:")
display(df1.head())
print()

# To display the last 5 rows
print("To display the last 5 rows:")
display(df1.tail())




display(df1.isnull().sum())
print()
print()

# Display the actual duplicate rows

display(df1[df1.duplicated()])
print()
print()

df1.nunique()
print()
print()
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25                 NaN
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 88   Volkswagen  Eurovan      Van   19.7        17                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21                 NaN
# 90   Volkswagen  Corrado   Sporty   23.3        18                 NaN
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0          140           5            26.5          11.0
# ...
